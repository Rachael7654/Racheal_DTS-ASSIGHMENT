# %% [markdown]
# <a href="https://colab.research.google.com/github/Rachael7654/Racheal_DTS-ASSIGHMENT/blob/main/WEEK6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Create student data
data = {
    "Name": ["John", "Mary", "Peter", "Grace", "Paul",
             "Anna", "David", "Ruth", "James", "Linda"],
    "Math": [70, 85, 40, 95, 60, 75, 88, 54, 67, 90],
    "English": [65, 90, 50, 92, 55, 80, 85, 60, 70, 93],
    "Science": [80, 88, 45, 98, 58, 78, 90, 65, 72, 95]
}

df = pd.DataFrame(data)

# Save to CSV
df.to_csv("students_week6.csv", index=False)

print("CSV file created successfully!")


df = pd.read_csv("students_week6.csv")
df.head()

subject_averages = df[["Math", "English", "Science"]].mean()
print("Subject Averages:\n", subject_averages)

df["Average"] = df[["Math", "English", "Science"]].mean(axis=1)
print("\nStudent Averages:\n", df[["Name", "Average"]])

top_student = df.loc[df["Average"].idxmax()]
print("\nTop Performing Student:\n", top_student["Name"], "-", round(top_student["Average"], 2))

lowest_student = df.loc[df["Average"].idxmin()]
print("Lowest Performing Student:\n", lowest_student["Name"], "-", round(lowest_student["Average"], 2))

df.to_csv("students_week6_updated.csv", index=False)
print("\nUpdated CSV exported successfully!")
# Out:
# CSV file created successfully!
# Subject Averages:
#  Math       72.4
# English    74.0
# Science    76.9
# dtype: float64
#
# Student Averages:
#      Name    Average
# 0   John  71.666667
# 1   Mary  87.666667
# 2  Peter  45.000000
# 3  Grace  95.000000
# 4   Paul  57.666667
# 5   Anna  77.666667
# 6  David  87.666667
# 7   Ruth  59.666667
# 8  James  69.666667
# 9  Linda  92.666667
#
# Top Performing Student:
#  Grace - 95.0
# Lowest Performing Student:
#  Peter - 45.0
#
# Updated CSV exported successfully!

# %% [markdown]
# NAME : MICHAEL RACHAEL BAIDU

# %% [markdown]
# MATRIC NUMBER : UJ/2025/CP/0371
