# %% [markdown]
# <a href="https://colab.research.google.com/github/Rachael7654/Racheal_DTS-ASSIGHMENT/blob/main/WEEK3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#create a list of 5 students scores
scores = [75, 88, 92, 64, 81]
print(scores)

#compute the average score
average = sum(scores) / len(scores)
print('average score:', average)

#find the highest score
highest = max(scores)
print('higest score:', highest)


#craete a dictionary with 5 students and scores
students = {'damian': 75,
            'paul': 88,
            'calebe': 92,
            'jerry': 64,
            'emma': 81,
            }
print(students)

#find the highest scoring student
highest_student = max(students, key=students.get)
print('highest scoring students:', highest_student)
print('highest score:', students[highest_student])

#create a tuple of subjects
subjects = ('maths', 'english', 'biology', 'physics', 'chemistry',)
print('subjects:', subjects)

#create a set of unique scores
unique_scores = set(students.values())
print('unique scores:', unique_scores)
# Out:
# [75, 88, 92, 64, 81]
# average score: 80.0
# higest score: 92
# {'damian': 75, 'paul': 88, 'calebe': 92, 'jerry': 64, 'emma': 81}
# highest scoring students: calebe
# highest score: 92
# subjects: ('maths', 'english', 'biology', 'physics', 'chemistry')
# unique scores: {64, 75, 81, 88, 92}

# %% [markdown]
# NAME : MICHAEL RACHAEL BAIDU

# %% [markdown]
# MATRIC NUMBER : UJ/2025/CP/0371
